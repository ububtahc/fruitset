# %%
# !pip install pandas
#!pip install seaborn
#!pip install openpyxl

# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_excel('Date_Fruit_Datasets.xlsx', sheet_name=None)
df=df['Date_Fruit_Datasets']
df
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1    338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2    526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3    416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4    347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..      ...        ...         ...         ...           ...       ...
# 893  255403  1925.3650    691.8453    477.1796        0.7241  570.2536
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
# 895  254330  1926.7360    747.4943    435.6219        0.8126  569.0545
# 896  238955  1906.2679    716.6485    441.8297        0.7873  551.5859
# 897  343792  2289.2720    823.8438    534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# ...

# %%
major_df= df["MAJOR_AXIS"]
major_df
# Out:
# 0      837.8484
# 1      723.8198
# 2      940.7379
# 3      827.9804
# 4      763.9877
#          ...
# 893    691.8453
# 894    855.4633
# 895    747.4943
# 896    716.6485
# 897    823.8438
# Name: MAJOR_AXIS, Length: 898, dtype: float64

# %%
class_df= df["Class"]
class_df
# Out:
# 0      BERHI
# 1      BERHI
# 2      BERHI
# 3      BERHI
# 4      BERHI
#        ...
# 893    SOGAY
# 894    SOGAY
# 895    SOGAY
# 896    SOGAY
# 897    SOGAY
# Name: Class, Length: 898, dtype: object

# %%
major_df= df[df["Class"]=="BERHI"]
major_df
# Out:
#       AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0   422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1   338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2   526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3   416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4   347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..     ...        ...         ...         ...           ...       ...
# 60  445290  2435.3889    857.8929    663.8074        0.6335  752.9680
# 61  375936  2255.8411    817.8654    589.0416        0.6937  691.8501
# 62  439650  2447.7371    890.0155    635.1306        0.7005  748.1843
# 63  433338  2423.3010    836.3414    664.9469        0.6065  742.7941
# 64  500669  2580.3069    913.3773    702.0745        0.6397  798.4182
#
#     SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# ...

# %%
minor_df= df[df["Class"]=="SOGAY"]
minor_df[['MINOR_AXIS', 'Class']]
# Out:
#      MINOR_AXIS  Class
# 804    497.2475  SOGAY
# 805    520.5521  SOGAY
# 806    535.5190  SOGAY
# 807    514.7833  SOGAY
# 808    513.4503  SOGAY
# ..          ...    ...
# 893    477.1796  SOGAY
# 894    551.5447  SOGAY
# 895    435.6219  SOGAY
# 896    441.8297  SOGAY
# 897    534.7757  SOGAY
#
# [94 rows x 2 columns]

# %%
perimeter_df= df[(df["Class"]=="SOGAY") & (df['PERIMETER']>2000)]
perimeter_df[['PERIMETER', 'Class']]
# Out:
#      PERIMETER  Class
# 804  1927.4420  SOGAY
# 805  2226.3210  SOGAY
# 806  2343.2290  SOGAY
# 807  2168.5410  SOGAY
# 808  2172.4651  SOGAY
# ..         ...    ...
# 893  1925.3650  SOGAY
# 894  2664.8230  SOGAY
# 895  1926.7360  SOGAY
# 896  1906.2679  SOGAY
# 897  2289.2720  SOGAY
#
# [94 rows x 2 columns]

# %%
df[(df["Class"]=="SOGAY") & (df['PERIMETER']>2000) & (df['AREA']>350000)]
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 806  378039  2343.2290    902.6270    535.5190        0.8050  693.7825
# 813  351763  2293.7791    878.5163    513.9243        0.8110  669.2373
# 819  365088  2249.6321    863.3080    541.9211        0.7784  681.7950
# 833  355294  2266.9509    870.8358    521.8104        0.8006  672.5878
# 835  363370  2249.0371    793.2402    586.2938        0.6736  680.1890
# 863  375569  2377.7141    953.8370    504.3600        0.8488  691.5123
# 879  376000  2405.4141    952.5737    506.6357        0.8468  691.9090
# 880  364338  2385.5110    849.6287    548.4377        0.7638  681.0944
# 887  373627  2634.6440    860.8875    555.6307        0.7638  689.7222
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 806    0.9889       382265  0.7876        1.6855  ...      2.2545      3.5794
# ...

# %%
df[["PERIMETER","AREA"]]
# Out:
#      PERIMETER    AREA
# 0    2378.9080  422163
# 1    2085.1440  338136
# 2    2647.3940  526843
# 3    2351.2100  416063
# 4    2160.3540  347562
# ..         ...     ...
# 893  1925.3650  255403
# 894  2664.8230  365924
# 895  1926.7360  254330
# 896  1906.2679  238955
# 897  2289.2720  343792
#
# [898 rows x 2 columns]

# %%
df[(df["Class"]=="SOGAY") & (df['PERIMETER']>2000) & (df['AREA']>350000)][['PERIMETER', 'Class', 'AREA']]
# Out:
#      PERIMETER  Class    AREA
# 806  2343.2290  SOGAY  378039
# 813  2293.7791  SOGAY  351763
# 819  2249.6321  SOGAY  365088
# 833  2266.9509  SOGAY  355294
# 835  2249.0371  SOGAY  363370
# 863  2377.7141  SOGAY  375569
# 879  2405.4141  SOGAY  376000
# 880  2385.5110  SOGAY  364338
# 887  2634.6440  SOGAY  373627
# 894  2664.8230  SOGAY  365924
